# %%
import pandas as pd
df=pd.read_csv("access to github.csv")

del df['Unnamed: 0']
df.head()
# Out:
#                    timestamp                        schema  version provider  \
# 0  2022-02-01 17:59:00+00:00  binderhub.jupyter.org/launch      5.0   GitHub
# 1  2022-02-01 18:37:00+00:00  binderhub.jupyter.org/launch      5.0   GitHub
# 2  2022-02-01 19:09:00+00:00  binderhub.jupyter.org/launch      5.0   GitHub
# 3  2022-02-01 21:02:00+00:00  binderhub.jupyter.org/launch      5.0   GitHub
# 4  2022-02-01 21:25:00+00:00  binderhub.jupyter.org/launch      5.0   GitHub
#
#                      spec                                       ref   status  \
# 0  weix1996/lectures/HEAD  836c546b6f09c7a1ed5c48de0f4d7fb2abdc840a  success
# 1  weix1996/lectures/HEAD  5782ee9f4b28d4ae47e14a2109cf3e34c178fc4b  success
# 2  weix1996/lectures/HEAD  5782ee9f4b28d4ae47e14a2109cf3e34c178fc4b  success
# 3  weix1996/lectures/HEAD  84c5f24631dd042cc321159e3c04b2e3827e0180  success
# 4  weix1996/lectures/HEAD  84c5f24631dd042cc321159e3c04b2e3827e0180  success
#
#    build_token              origin
# 0          1.0    gke.mybinder.org
# 1          1.0  gesis.mybinder.org
# 2          1.0    gke.mybinder.org
# 3          1.0    gke.mybinder.org
# 4          1.0    gke.mybinder.org

# %%
temp=df['timestamp'].to_list()
temp[4][5:10]
# Out:
# '02-01'

# %%
temp=[]
for i in df['timestamp'].to_list():
    temp.append(i[5:10])
df['timestamp']=temp
#df.set_index('timestamp',inplace=True)
df.head(1)
# Out:
#   timestamp                        schema  version provider  \
# 0     02-01  binderhub.jupyter.org/launch      5.0   GitHub
#
#                      spec                                       ref   status  \
# 0  weix1996/lectures/HEAD  836c546b6f09c7a1ed5c48de0f4d7fb2abdc840a  success
#
#    build_token            origin
# 0          1.0  gke.mybinder.org

# %%
"""i=0
date_time_list=[]
while i<len(df['timestamp']):
    date_time_list.append(df['timestamp'][i][:10])
    
    i=i+1
    if i%600==0:
        print(i)
dates=pd.to_datetime(date_time_list)
df['date']=dates
df.head(1)"""
# Out:
# "i=0\ndate_time_list=[]\nwhile i<len(df['timestamp']):\n    date_time_list.append(df['timestamp'][i][:10])\n    \n    i=i+1\n    if i%600==0:\n        print(i)\ndates=pd.to_datetime(date_time_list)\ndf['date']=dates\ndf.head(1)"

# %%
test=df.copy()
test=(test['timestamp'].value_counts())
test.sort_index(inplace=True)

x1=test.loc[:'06-15']
x2=test.loc['08-20':]

# %%
fall_dates=x2.index.to_list()
fall_dates.insert(37,'10_01')
fall_values=x2.to_list()
fall_values.insert(37,0)

fall_dates.extend(['11-01','12-01'])
fall_values.extend([0,0])

# %%
fall_values
# Out:
# [1,
#  5,
#  12,
#  30,
#  1,
#  1,
#  9,
#  9,
#  4,
#  9,
#  1,
#  1,
#  8,
#  3,
#  22,
#  22,
#  7,
#  1,
#  2,
#  3,
#  16,
#  10,
#  12,
#  2,
#  2,
#  8,
#  27,
#  19,
#  2,
#  9,
#  2,
#  4,
#  2,
#  10,
#  9,
#  32,
#  18,
#  0,
#  2,
#  3,
#  3,
#  1,
#  1,
#  1,
#  14,
#  12,
#  12,
#  34,
#  35,
#  5,
#  11,
#  33,
#  14,
#  0,
#  0]

# %%
fall_months=["09-01","10-01",'11-01','12-01']

# %%
fig,ax=plt.subplots()
ax.plot(x2.index.to_list(),x2.to_list(),label="Fall 2022",color="red")
ax.set_xticks(fall_months)
# Out:
# [<matplotlib.axis.XTick at 0x1a7a27c6850>,
#  <matplotlib.axis.XTick at 0x1a7a27c66d0>,
#  <matplotlib.axis.XTick at 0x1a7a29001c0>,
#  <matplotlib.axis.XTick at 0x1a7a078a3d0>]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, (ax,ax2) = plt.subplots(1,2,figsize=(14,9),sharey=True)
ax.plot(x1.index.to_list(),x1.to_list(),label="Spring 2022",color="green")
ax2.plot(color='green',label="Spring 2022")
ax2.plot(fall_dates,fall_values,label="Fall 2022",color="red")


ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

ax.yaxis.tick_left()
ax2.tick_params(labelright='on')
ax2.yaxis.tick_right()

d = .012 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)

fig.subplots_adjust(wspace = 0.05)

#spring avg
ax2.axhline(y=x1.mean(),color="purple", label='Daily Average - Spring',linestyle='--' )
ax.axhline(y=x1.mean(),color="purple", linestyle='--' )

#fall avg
ax2.axhline(y=x2.mean(),color="orange", label='Daily Average - Fall ',linestyle='--' )
ax.axhline(y=x2.mean(),color="orange", linestyle='--' )

#guidelines
for i in range(0,120,10):
    if i==10:
        continue
    ax.axhline(y=i,color="black",linestyle="--",alpha=.2)
    ax2.axhline(y=i,color="black",linestyle="--",alpha=.2)
#creating the legend
handles,labels=ax.get_legend_handles_labels()
handles2,labels2=ax2.get_legend_handles_labels()
handles.extend(handles2)
plt.legend(handles=handles,loc='upper left')

ax.set_xlabel('Days [Spring]')        
ax2.set_xlabel('Days [Fall]')   
ax.set_ylabel('Times Accessed')

#creating the legend
handles,labels=ax.get_legend_handles_labels()
handles2,labels2=ax2.get_legend_handles_labels()
handles.extend(handles2)
plt.legend(handles=handles,loc='upper left')

ax.set_title('How often per day the class lectures were accessed')
ax2.set_xticks(fall_months)
ax.set_xticks(['02-01','03-01','04-01','05-01'])


ax.set_xlabel('Days [Spring]')        
ax2.set_xlabel('Days [Fall]')   
ax.set_ylabel('Times Accessed')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, (ax,ax2) = plt.subplots(1,2,figsize=(14,9),sharey=True,sharex=False)
ax.plot(x1.index.to_list(),x1.to_list(),label="Spring 2022",color="green")
ax2.plot(color='green',label="Spring 2022")
ax2.plot(x2.index.to_list(),x2.to_list(),label="Fall 2022",color="red")


ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

ax.yaxis.tick_left()
ax2.tick_params(labelright='on')
ax2.yaxis.tick_right()

d = .012 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)

fig.subplots_adjust(wspace = 0.05)

#spring avg
ax2.axhline(y=x1.mean(),color="purple", label='Daily Average - Spring',linestyle='--' )
ax.axhline(y=x1.mean(),color="purple", linestyle='--' )

#fall avg
ax2.axhline(y=x2.mean(),color="orange", label='Daily Average - Fall ',linestyle='--' )
ax.axhline(y=x2.mean(),color="orange", linestyle='--' )

#guidelines
for i in range(0,120,10):
    if i==10:
        continue
    ax.axhline(y=i,color="black",linestyle="--",alpha=.2)
    ax2.axhline(y=i,color="black",linestyle="--",alpha=.2)

ax.set_title('How often per day the class lectures were accessed')
ax.set_xticks(['02-01','03-01','04-01','05-01'])
ax2.set_xticks(['08-22','09-01','10-01','11-01','12-01'])
ax.set_yticks([0,x1.mean(),x2.mean(),20,30,40,50,60,70,80,90,100,110,120])
ax2.set_yticks([0,x1.mean(),x2.mean(),20,30,40,50,60,70,80,90,100,110,120])

#homework days
hw_fall_days=["09-06","09-19","09-28","10-17","10-24"]
for i in hw_fall_days[1:]:
    ax2.axvline(x=i, color='cyan',linestyle='--',alpha=.4)
ax2.axvline(x='09-06', color='cyan',linestyle='--',alpha=.4,label='homework')

fall_months=["09-01","10-01",'11-01','12-01']
for i in fall_months:
    ax2.axvline(x=i, color='green',linestyle='--',alpha=1)



ax2.set_xticks(fall_months)
#midterm
ax2.axvline(x='10-13', color='blue',linestyle='--',alpha=.4,label='midterm')

#creating the legend
handles,labels=ax.get_legend_handles_labels()
handles2,labels2=ax2.get_legend_handles_labels()
handles.extend(handles2)
plt.legend(handles=handles,loc='upper left')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

#colors = ["green", "red","purple","orange"]
#texts = ["Spring 2022", " Fall 2022","Spring 2022 average access/day","Fall 2022 average access/day"]

fig, (ax,ax2) = plt.subplots(1,2,figsize=(14,9),sharey=True)
ax.plot(x1.index.to_list(),x1.to_list(),label="Spring 2022",color="green")
ax2.plot(color='green',label="Spring 2022")
ax2.plot(x2.index.to_list(),x2.to_list(),label="Fall 2022",color="red")


ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

ax.yaxis.tick_left()
ax2.tick_params(labelright='on')
ax2.yaxis.tick_right()

d = .012 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)

fig.subplots_adjust(wspace = 0.05)


#spring avg
ax2.axhline(y=x1.mean(),color="purple", label='Daily Average - Spring',linestyle='--' )
ax.axhline(y=x1.mean(),color="purple", linestyle='--' )


#fall avg
ax2.axhline(y=x2.mean(),color="orange", label='Daily Average - Fall ',linestyle='--' )
ax.axhline(y=x2.mean(),color="orange", linestyle='--' )


# line at y=0
ax.axhline(y=0,color="black",linestyle="--")
ax2.axhline(y=0,color="black",linestyle="--")



ax.set_title('How often per day the class lectures were accessed')
ax.set_xticks(['2022-02-01','2022-03-01','2022-04-01','2022-05-01'])
ax2.set_xticks(['2022-09-01','2022-10-01',]) #'2022-11-01','2022-12-01'])


#creating the legend
handles,labels=ax.get_legend_handles_labels()
handles2,labels2=ax2.get_legend_handles_labels()
handles.extend(handles2)
plt.legend(handles=handles,loc='upper right')



plt.show()

# %%
a1_list=[]
a2_list=[]
for a1,b1 in enumerate(x1.to_list()):
    a1_list.append(a1)

for a2,b2 in enumerate(x2.to_list()):
    a2_list.append(a2)

# %%
fig,ax=plt.subplots(figsize=(14,8))


ax.plot(a1_list,x1.to_list(),label="Spring 2022",color="green")
ax.plot(a2_list,x2.to_list(),label="Fall 2022",color="red")

ax.legend()
plt.show()
